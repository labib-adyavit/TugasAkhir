# %%
##Data exploration
#Importing table and visualization libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading .csv file for complete, cleaned dataset
df_path='D:\[TUGAS AKHIR]\[TA Abdur]\llzo_dataset_clean.csv'
df_raw=pd.read_csv(df_path)
df = df_raw[0:176]
df.head(176)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-982718ea7770> in <module>
#       1 # Reading .csv file for complete, cleaned dataset
#       2 df_path='D:\[TUGAS AKHIR]\[TA Abdur]\llzo_dataset_clean.csv'
# ----> 3 df_raw=pd.read_csv(df_path)
#       4 df = df_raw[0:176]
#       5 df.head(176)
#
# NameError: name 'pd' is not defined

# %%
#Dropping unnecessary columns for prediction
df = df.drop(['conductivity','good_cond','li_dopant','la_dopant','zr_dopant','source'], axis=1)
df.head()

#Describing the dataset
df.describe()
# Out:
#            li_sto      la_sto      zr_sto  li_dop_sto  la_dop_sto  zr_dop_sto  \
# count  176.000000  176.000000  176.000000  176.000000  176.000000  176.000000
# mean     6.512642    2.990625    1.762330    0.095028    0.026193    0.235909
# std      0.347257    0.160727    0.316082    0.119197    0.089754    0.316631
# min      5.000000    2.400000    0.000000    0.000000    0.000000    0.000000
# 25%      6.277500    3.000000    1.600000    0.000000    0.000000    0.000000
# 50%      6.500000    3.000000    1.900000    0.000000    0.000000    0.087500
# 75%      6.750000    3.000000    2.000000    0.200000    0.000000    0.400000
# max      7.420000    4.000000    2.070000    0.500000    0.600000    2.000000
#
#        rel_dens_%    log_cond  li_dop_ionicrad  la_dop_ionicrad  \
# count  113.000000  176.000000       176.000000       176.000000
# mean    90.986575   -3.730784        25.812500        21.034091
# std      5.672351    0.758431        28.811586        51.150970
# min     66.000000   -7.853872         0.000000         0.000000
# 25%     88.400000   -4.000000         0.000000         0.000000
# 50%     92.190000   -3.572695         0.000000         0.000000
# 75%     95.000000   -3.235523        55.000000         0.000000
# max     99.900000   -2.686133        63.000000       175.000000
#
#        zr_dop_ionicrad  li_dop_enev  la_dop_enev  zr_dop_enev
# count       176.000000   176.000000   176.000000   176.000000
# mean         41.881250     0.779716     0.139659     0.949489
# std          39.088197     0.869683     0.337715     0.911157
# min           0.000000     0.000000     0.000000     0.000000
# 25%           0.000000     0.000000     0.000000     0.000000
# 50%          73.000000     0.000000     0.000000     1.500000
# 75%          78.000000     1.810000     0.000000     1.600000
# max         109.800000     2.010000     1.120000     2.360000

# %%
#Finding correlation between features
corr = df.corr()
plt.subplots(figsize=(10,10))
ax = sns.heatmap(
    corr,
    vmin = -1, vmax = 1, center = 0,
    linewidths = .5, annot = True,
    cmap = sns.diverging_palette(20, 220, n = 200),
    square = True)
corr

#Heatmap description
corr['log_cond'].describe()
# Out:
# count    14.000000
# mean      0.158849
# std       0.341325
# min      -0.219613
# 25%      -0.078742
# 50%       0.026114
# 75%       0.266158
# max       1.000000
# Name: log_cond, dtype: float64

# %%
#Finding missing values distribution on dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176 entries, 0 to 175
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   li_sto           176 non-null    float64
#  1   la_sto           176 non-null    float64
#  2   zr_sto           176 non-null    float64
#  3   li_dop_sto       176 non-null    float64
#  4   la_dop_sto       176 non-null    float64
#  5   zr_dop_sto       176 non-null    float64
#  6   rel_dens_%       113 non-null    float64
#  7   log_cond         176 non-null    float64
#  8   li_dop_ionicrad  176 non-null    float64
#  9   la_dop_ionicrad  176 non-null    float64
#  10  zr_dop_ionicrad  176 non-null    float64
#  11  li_dop_enev      176 non-null    float64
#  12  la_dop_enev      176 non-null    float64
#  13  zr_dop_enev      176 non-null    float64
# dtypes: float64(14)
# memory usage: 19.4 KB

# %%
#Making scatter plots to illustrate feature data distribution in respect to log_cond
for col in df.columns.values:
    if col == 'log_cond':
        continue
    plt.figure(figsize=(20,5))
    sns.scatterplot(df.dropna()[col], df.dropna()['log_cond'])
    plt.title(col)
    plt.show()
# Out:
# C:\Users\Muhammad Labib\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Muhammad Labib\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Muhammad Labib\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Muhammad Labib\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Muhammad Labib\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Muhammad Labib\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Muhammad Labib\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Muhammad Labib\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Muhammad Labib\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Muhammad Labib\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Muhammad Labib\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Muhammad Labib\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Muhammad Labib\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import lazypredict

#Importing dataset splitting and imputing libraries
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer

#Defining X (features) and y (target property) for cut dataset
X = df.dropna().drop('log_cond', axis=1)
y = df.dropna()['log_cond']
#Splitting
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

#Defining X (features) and y (target property) for imputed dataset
X_imp = df.drop('log_cond', axis=1)
y_imp = df.log_cond
#Splitting
X_train_imp, X_test_imp, y_train_imp, y_test_imp = train_test_split(X_imp, y_imp, test_size=0.25, random_state=42)

#Imputing X_train_imp
my_imputer = SimpleImputer(strategy = 'mean')
imputed_X_train = pd.DataFrame(my_imputer.fit_transform(X_train_imp))
imputed_X_train.columns = X_train_imp.columns
imputed_X_train.index = X_train_imp.index

#Imputing X_test_imp
imputed_X_test = pd.DataFrame(my_imputer.transform(X_test_imp))
imputed_X_test.columns = X_test_imp.columns
imputed_X_test.index = X_test_imp.index

# %%
#Importing necessary libraries for LazyRegressor
from lazypredict.Supervised import LazyRegressor
from sklearn import datasets
from sklearn.utils import shuffle
import numpy as np

#Using LazyRegressor for cut dataset
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)

print(models)
# Out:
# C:\Users\Muhammad Labib\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)
#  26%|██▌       | 11/43 [00:02<00:09,  3.55it/s]
# GammaRegressor model failed to execute
# Some value(s) of y are out of the valid range for family GammaDistribution
#  72%|███████▏  | 31/43 [00:07<00:02,  4.14it/s]
# PoissonRegressor model failed to execute
# Some value(s) of y are out of the valid range for family PoissonDistribution
#  88%|████████▊ | 38/43 [00:09<00:01,  3.12it/s]
# StackingRegressor model failed to execute
# __init__() missing 1 required positional argument: 'estimators'
# 100%|██████████| 43/43 [00:11<00:00,  3.61it/s]
#                                R-Squared  RMSE  Time Taken
# Model
# RandomForestRegressor               0.52  0.48        1.25
# BaggingRegressor                    0.50  0.49        0.17
# OrthogonalMatchingPursuit           0.48  0.50        0.05
# LassoLarsIC                         0.45  0.51        0.07
# BayesianRidge                       0.44  0.52        0.06
# SGDRegressor                        0.44  0.52        0.05
# KNeighborsRegressor                 0.43  0.52        0.04
# RidgeCV                             0.43  0.52        0.10
# LassoLarsCV                         0.43  0.52        0.08
# LarsCV                              0.43  0.52        0.16
# Ridge                               0.43  0.52        0.07
# LassoCV                             0.42  0.52        1.00
# ElasticNetCV                        0.42  0.52        0.72
# SVR                                 0.41  0.53        0.10
# TweedieRegressor                    0.40  0.53        0.23
# GeneralizedLinearRegressor          0.40  0.53        0.07
# NuSVR                               0.40  0.54        0.07
# ExtraTreesRegressor                 0.35  0.55        1.03
# OrthogonalMatchingPursuitCV         0.33  0.56        0.10
# GradientBoostingRegressor           0.32  0.57        0.26
# LinearSVR                           0.28  0.58        0.05
# PassiveAggressiveRegressor          0.28  0.59        0.07
# HistGradientBoostingRegressor       0.27  0.59        0.42
# AdaBoostRegressor                   0.22  0.61        0.54
# LGBMRegressor                       0.21  0.61        0.17
# ElasticNet                          0.12  0.64        0.05
# XGBRegressor                        0.08  0.66        0.84
# DecisionTreeRegressor               0.07  0.66        0.04
# LinearRegression                    0.06  0.67        0.03
# TransformedTargetRegressor          0.06  0.67        1.01
# Lars                                0.06  0.67        0.08
# Lasso                              -0.02  0.69        0.04
# DummyRegressor                     -0.02  0.69        0.04
# LassoLars                          -0.02  0.69        0.03
# HuberRegressor                     -0.17  0.75        0.18
# MLPRegressor                       -0.26  0.77        1.62
# RANSACRegressor                    -0.33  0.79        0.65
# ExtraTreeRegressor                 -0.60  0.87        0.06
# GaussianProcessRegressor           -3.23  1.42        0.07
# KernelRidge                       -29.91  3.83        0.03

# %%
#Using LazyRegressor for imputed dataset
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models, predictions = reg.fit(imputed_X_train, imputed_X_test, y_train_imp, y_test_imp)

print(models)
# Out:
#  26%|██▌       | 11/43 [00:02<00:07,  4.28it/s]
# GammaRegressor model failed to execute
# Some value(s) of y are out of the valid range for family GammaDistribution
#  72%|███████▏  | 31/43 [00:07<00:02,  4.04it/s]
# PoissonRegressor model failed to execute
# Some value(s) of y are out of the valid range for family PoissonDistribution
#  88%|████████▊ | 38/43 [00:09<00:01,  3.45it/s]
# StackingRegressor model failed to execute
# __init__() missing 1 required positional argument: 'estimators'
# 100%|██████████| 43/43 [00:10<00:00,  4.04it/s]
#                                R-Squared  RMSE  Time Taken
# Model
# GradientBoostingRegressor           0.77  0.40        0.25
# RandomForestRegressor               0.61  0.53        1.10
# BaggingRegressor                    0.60  0.53        0.14
# OrthogonalMatchingPursuitCV         0.58  0.55        0.07
# OrthogonalMatchingPursuit           0.58  0.55        0.04
# XGBRegressor                        0.57  0.55        0.31
# ExtraTreesRegressor                 0.56  0.56        0.51
# SGDRegressor                        0.55  0.56        0.09
# TransformedTargetRegressor          0.54  0.57        0.33
# LinearRegression                    0.54  0.57        0.33
# Lars                                0.54  0.57        0.06
# RidgeCV                             0.53  0.57        0.05
# LassoCV                             0.53  0.57        1.13
# ElasticNetCV                        0.53  0.58        1.16
# LassoLarsCV                         0.53  0.58        0.18
# LarsCV                              0.53  0.58        0.15
# Ridge                               0.53  0.58        0.05
# BayesianRidge                       0.53  0.58        0.05
# LassoLarsIC                         0.53  0.58        0.10
# AdaBoostRegressor                   0.52  0.58        0.28
# SVR                                 0.52  0.58        0.08
# HuberRegressor                      0.51  0.59        0.18
# LinearSVR                           0.50  0.59        0.07
# NuSVR                               0.48  0.61        0.06
# MLPRegressor                        0.46  0.62        1.74
# HistGradientBoostingRegressor       0.44  0.63        0.49
# KNeighborsRegressor                 0.44  0.63        0.05
# DecisionTreeRegressor               0.44  0.63        0.04
# LGBMRegressor                       0.44  0.63        0.14
# GeneralizedLinearRegressor          0.36  0.67        0.07
# TweedieRegressor                    0.36  0.67        0.07
# ExtraTreeRegressor                  0.16  0.77        0.03
# Lasso                              -0.00  0.84        0.09
# ElasticNet                         -0.00  0.84        0.05
# DummyRegressor                     -0.00  0.84        0.04
# LassoLars                          -0.00  0.84        0.09
# RANSACRegressor                    -0.49  1.03        0.57
# PassiveAggressiveRegressor         -0.57  1.05        0.05
# KernelRidge                       -19.20  3.78        0.06
# GaussianProcessRegressor         -132.65  9.73        0.13
