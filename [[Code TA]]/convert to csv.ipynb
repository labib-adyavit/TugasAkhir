# %%
#importing pandas as pd
import pandas as pd
  
# Read and store content
# of an excel file 
read_file = pd.read_excel (r'C:\Users\Muhammad Labib\Desktop\TA_sementara.xlsx')
  
# Write the dataframe object
# into csv file
read_file.to_csv (r"TA_sementara.csv", 
                  index = None,
                  header=True)
    
# read csv file and convert 
# into a dataframe object
df = pd.DataFrame(pd.read_csv(r"TA_sementara.csv"))
  
# show the dataframe
df
# Out:
#      Li_sto  Ni_sto  Co_sto  Mn_sto  sint_temp  sint_time  dop_ionrad  \
# 0       1.0   0.800   0.100   0.100        750       15.0       0.000
# 1       1.0   0.790   0.100   0.100        750       15.0       1.170
# 2       1.0   0.770   0.100   0.100        750       15.0       1.170
# 3       1.0   0.800   0.100   0.100        850       20.0       0.000
# 4       1.0   0.792   0.099   0.099        850       20.0       0.605
# ..      ...     ...     ...     ...        ...        ...         ...
# 144     1.0   0.800   0.100   0.100        800       12.0       0.000
# 145     1.0   0.800   0.100   0.099        800       12.0       0.720
# 146     1.0   0.850   0.100   0.050        760        6.0       0.000
# 147     1.0   0.850   0.100   0.050        760        6.0       0.535
# 148     1.0   0.850   0.100   0.050        760        6.0       0.605
#
#      dop_sto   xrd_a    xrd_c       Rca  %_catmix  init_cap       %_cr
# ...

# %%
df.describe()
# Out:
#            Li_sto      Ni_sto      Co_sto      Mn_sto   sint_temp   sint_time  \
# count  149.000000  149.000000  149.000000  149.000000  149.000000  145.000000
# mean     0.999038    0.754174    0.122426    0.116044  806.442953   13.572414
# std      0.004159    0.089740    0.039916    0.052123   37.309404    3.388594
# min      0.970000    0.588000    0.050000    0.025000  750.000000    6.000000
# 25%      1.000000    0.700000    0.100000    0.098000  800.000000   12.000000
# 50%      1.000000    0.800000    0.100000    0.100000  800.000000   14.000000
# 75%      1.000000    0.800000    0.120000    0.150000  830.000000   15.000000
# max      1.000000    0.900000    0.200000    0.200000  900.000000   24.000000
#
#        dop_ionrad     dop_sto       xrd_a       xrd_c         Rca    %_catmix  \
# count  147.000000  146.000000  140.000000  140.000000  140.000000   94.000000
# mean     0.487177    0.013748    2.870814   14.207275    4.948856   10.270814
# ...
